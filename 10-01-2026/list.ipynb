# %%
list=[3214,"Suyash"]
print(list)
# Out:
# [3214, 'Suyash']

# %%
list.append("CSE")
print(list)
# Out:
# [3214, 'Suyash', 'CSE', 'CSE']

# %%
list.insert(2,"Branch")
print(list)
# Out:
# [3214, 'Suyash', 'Branch', 'CSE', 'CSE']

# %%
list.append("CSE")
print(list)
# Out:
# [3214, 'Suyash', 'Branch', 'CSE']

# %%
list.pop()
print(list)
# Out:
# [3214, 'Suyash', 'Branch']
