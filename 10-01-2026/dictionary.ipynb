# %%
student={
    "name":"Suyash",
    "class": 12,
    "marks":89.2
}
print(student)
# Out:
# {'name': 'Suyash', 'class': 12, 'marks': 89.2}

# %%
print(student["name"])
# Out:
# Suyash

# %%
print(student.get("class"))
# Out:
# 12

# %%
student["marks"] =90
print(student)
# Out:
# {'name': 'Suyash', 'class': 12, 'marks': 90}

# %%
student["rollno"]=3214
print(student)
# Out:
# {'name': 'Suyash', 'class': 12, 'marks': 90, 'rollno': 3214}

# %%
student["rollno"]=3214
print(student)
removed_value= student.pop("rollno")
print("Removed Item:" , removed_value)
print(student)
del student["marks"]
print(student)
# Out:
# {'name': 'Suyash', 'class': 12, 'rollno': 3214}
# Removed Item: 3214
# {'name': 'Suyash', 'class': 12}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 6
#       4 print("Removed Item:" , removed_value)
#       5 print(student)
# ----> 6 del student["marks"]
#       7 print(student)
#
# KeyError: 'marks'

# %%
print(student.keys())
print(student.values())
# Out:
# dict_keys(['name', 'class'])
# dict_values(['Suyash', 12])

# %%
student.update({"gender":"male"})
print(student)
# Out:
# {'name': 'Suyash', 'class': 12, 'gender': 'male'}
