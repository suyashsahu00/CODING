# %% [markdown]
# # Operator
# arithmetic
# comparison
# assignment
# logical
# identity
# membership
# bitwise
# membership
# bitwise

# %%
# aritmentic
a=10 
b=5
print("hello",a+b) #15
print(a-b) #5
print(a/b) #2
print(a%b) #0
print(a//b) #2
print(a**b) #100000
# Out:
# hello 15
# 5
# 2.0
# 0
# 2
# 100000

# %%
# comparision(relational)
print(a==b) # false
print(a!=b) #true
print(a>b) #false
print(a<b) #true
# Out:
# False
# True
# False
# True

# %%
# assiment
x =5
print(x) #5
x+=2
print(x) #7
# Out:
# 5
# 7

# %%
# logical
print(1 and 0) #false
print(1 or 0) #true
# print(1 not 0) #true
# Out:
# 0
# 1

# %%
alphabet ={"a","b"}
print("a" in alphabet) #T
print("b" not in alphabet) # F
# Out:
# True
# False

# %%
print(a & b) #

# %%
import keyword
print(keyword.kwlist )
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
name = "Suyash"
age = 20
print(f"my name is {name} and my age {age}")
# Out:
# my name is Suyash and my age 20

# %%
input("Enter a name: ")
# Out:
# '1'

# %%
int(input("Enter a name1: "))
# Out:
# 1

# %%
# geting useer detail
first_name= input("Enter your first name : ")
second_name= input("Enter your second name : ")

#typecasting
age = int (input("Enter your age: "))

#formating

print(f"My first name is {first_name} and second name is {second_name} and my age is {age}")
# Out:
# My first name is Suyash and second name is Sahu and my age is 21
