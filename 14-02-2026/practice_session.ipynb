# %% [markdown]
# # Data Analysis Practice Session
# Welcome to your practice session! I will guide you through analyzing the `sales_data.csv` file.
#
# ## Question 1: Loading the Data
# **Task:** Import the `pandas` library and load the `sales_data.csv` file into a variable called `df`.
# Then, display the first 5 rows to check if it loaded correctly.

# %%
import pandas as pd

df = pd.read_csv("sales_data.csv")
df.head()
# Out:
#    TransactionID        Date Region     Product     Category  UnitsSold  \
# 0           1001  2024-01-01  North      Laptop  Electronics          2
# 1           1002  2024-01-02  South       Mouse  Accessories         10
# 2           1003  2024-01-02   East    Keyboard  Accessories          5
# 3           1004  2024-01-03   West     Monitor  Electronics          3
# 4           1005  2024-01-04  North  Headphones  Accessories          8
#
#    UnitPrice  TotalRevenue CustomerType PaymentMethod
# 0        800          1600       Member   Credit Card
# 1         25           250       Normal          Cash
# 2         45           225       Member        PayPal
# 3        200           600       Member   Credit Card
# 4         50           400       Normal   Credit Card
